# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
# from dataProcessing import PARTS, requiredParts

# %%
# Load the 2 files
FILE_1 = "squat3"
FILE_2 = "squatfar4"

squat1X = np.load("./data/"+FILE_1+"X.npy")
squat1Y = np.load("./data/"+FILE_1+"Y.npy")
squat2X = np.load("./data/"+FILE_2+"X.npy")
squat2Y = np.load("./data/"+FILE_2+"Y.npy")

# %%
# Find and plot convolution

def convSquat(sig, win):
    filtered = signal.convolve(sig, win)
    fig, (ax_orig, ax_win, ax_filt) = plt.subplots(3, 1, sharex=True)
    ax_orig.plot(sig)
    ax_orig.set_title('Original pulse')
#     ax_orig.margins(0, 0.1)
    ax_win.plot(win)
    ax_win.set_title('Filter impulse response')
#     ax_win.margins(0, 0.1)
    ax_filt.plot(filtered)
    ax_filt.set_title('Convolved signal')
#     ax_filt.margins(0, 0.1)
    fig.tight_layout()
    fig.show()

convSquat(squat1Y[0:25,0], squat2Y[20:70,0])
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
